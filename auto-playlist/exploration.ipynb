# %% [markdown]
# # Exploration
# ***

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import utils
import pandas as pd
import numpy as np

# %%
client_id = 'b962565806ca4496996ae576320a957f'
client_secret = '1d61927e4edc401e91fa6b350c089c7b'
scope = 'user-library-read'

# %%
token = spotipy.util.prompt_for_user_token(username='1120649038', scope=scope, client_id=client_id, client_secret=client_secret, redirect_uri = 'http://localhost/')

# %%
sp = spotipy.Spotify(auth=token)

# %%
# cm = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
# sp = spotipy.Spotify(client_credentials_manager=cm)

# %%
sp.current_user_playlists()
# Out:
# {'href': 'https://api.spotify.com/v1/users/1120649038/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': 'Up for a nostalgic running session that brings a smile to your face? Press play!',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4osfY3zybD2'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4osfY3zybD2',
#    'id': '37i9dQZF1DX4osfY3zybD2',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000002205d0e9dc02aa617347d472f',
#      'width': None}],
#    'name': "Runner's Club 160 BPM",
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': False,
# ...

# %%
tracks = utils.get_playlist_tracks('library', sp)

# %%
df = pd.DataFrame(tracks)

# %%
df.head()
# Out:
#                               track_uri                             album_uri  \
# 0  spotify:track:4ffXndH7BjJLaKIenlxhUX  spotify:album:1rBx7gOHgsMr2JN9zDuUAY
# 1  spotify:track:2M53FYJ8EE9pyZNHIr43Zo  spotify:album:7MnZ0niFxkTVJkEX9pakbM
# 2  spotify:track:0ggGTGpdhiWCQHY7UoNDI2  spotify:album:6jJE2t5ZfWq3I7n5KhF89d
# 3  spotify:track:7aE5WXu5sFeNRh3Z05wwu4  spotify:album:6uvBKDGlJAYLH5Vy6RQVsc
# 4  spotify:track:27oiVZe7W0lXNaRGP9toGr  spotify:album:7MnZ0niFxkTVJkEX9pakbM
#
#   album_type                                         album_name  \
# 0     single                                     Treasured Soul
# 1      album                                    Compilation 1.1
# 2      album                        ASA (Asha) [Deluxe Edition]
# 3      album  Wish You Were Here [Remastered] (Remastered Ve...
# 4      album                                    Compilation 1.1
#
#    album_total_tracks                                                img  \
# ...

# %%
df.sort_values('artist_followers', ascending=False).head()['artist_name']
# Out:
# 27        Ed Sheeran
# 335            Drake
# 245            Drake
# 242    Ariana Grande
# 176         Coldplay
# Name: artist_name, dtype: object

# %%
df.hist('artist_followers', bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0A653DF0>]],
#       dtype=object)

# %%
df['artist_name'].value_counts(ascending=False).hist()

# %%
df.hist('artist_popularity')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0A6D65B0>]],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434 entries, 0 to 433
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   track_uri               434 non-null    object
#  1   album_uri               434 non-null    object
#  2   album_type              434 non-null    object
#  3   album_name              434 non-null    object
#  4   album_total_tracks      434 non-null    int64
#  5   img                     434 non-null    object
#  6   track_name              434 non-null    object
#  7   release_date            434 non-null    object
#  8   release_date_precision  434 non-null    object
#  9   explicit                434 non-null    bool
#  10  track_popularity        434 non-null    int64
#  11  preview_url             340 non-null    object
#  12  artist_name             434 non-null    object
#  13  artist_uri              434 non-null    object
# ...

# %%
df.hist('tempo')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0BB9B310>]],
#       dtype=object)
